# %% [markdown]
# # Imports

# %%
# !pip install openml
# Out:
# Collecting openml
#   Downloading openml-0.14.1.tar.gz (131 kB)
#      -------------------------------------- 131.3/131.3 kB 3.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting liac-arff>=2.4.0
#   Downloading liac-arff-2.5.0.tar.gz (13 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting xmltodict
#   Using cached xmltodict-0.13.0-py2.py3-none-any.whl (10.0 kB)
# Requirement already satisfied: requests in c:\users\bianc\appdata\roaming\python\python310\site-packages (from openml) (2.31.0)
# Requirement already satisfied: scikit-learn>=0.18 in c:\users\bianc\anaconda3\lib\site-packages (from openml) (1.2.1)
# Requirement already satisfied: python-dateutil in c:\users\bianc\anaconda3\lib\site-packages (from openml) (2.8.2)
# Requirement already satisfied: pandas>=1.0.0 in c:\users\bianc\anaconda3\lib\site-packages (from openml) (1.5.3)
# Requirement already satisfied: scipy>=0.13.3 in c:\users\bianc\anaconda3\lib\site-packages (from openml) (1.10.0)
# Requirement already satisfied: numpy>=1.6.2 in c:\users\bianc\anaconda3\lib\site-packages (from openml) (1.23.5)
# Collecting minio
#   Downloading minio-7.1.17-py3-none-any.whl (78 kB)
#      ---------------------------------------- 78.3/78.3 kB 4.5 MB/s eta 0:00:00
# Collecting pyarrow
#   Downloading pyarrow-13.0.0-cp310-cp310-win_amd64.whl (24.3 MB)
#      ---------------------------------------- 24.3/24.3 MB 4.3 MB/s eta 0:00:00
# Requirement already satisfied: pytz>=2020.1 in c:\users\bianc\anaconda3\lib\site-packages (from pandas>=1.0.0->openml) (2022.7)
# Requirement already satisfied: six>=1.5 in c:\users\bianc\anaconda3\lib\site-packages (from python-dateutil->openml) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\bianc\anaconda3\lib\site-packages (from scikit-learn>=0.18->openml) (2.2.0)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\bianc\anaconda3\lib\site-packages (from scikit-learn>=0.18->openml) (1.1.1)
# Requirement already satisfied: urllib3 in c:\users\bianc\anaconda3\lib\site-packages (from minio->openml) (1.26.14)
# Requirement already satisfied: certifi in c:\users\bianc\anaconda3\lib\site-packages (from minio->openml) (2022.12.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\bianc\anaconda3\lib\site-packages (from requests->openml) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\bianc\anaconda3\lib\site-packages (from requests->openml) (3.4)
# Building wheels for collected packages: openml, liac-arff
#   Building wheel for openml (setup.py): started
#   Building wheel for openml (setup.py): finished with status 'done'
#   Created wheel for openml: filename=openml-0.14.1-py3-none-any.whl size=146951 sha256=520791cd4b1d88db3096f60300bbf1775a95022d3bcfc4db747e47764db89d91
#   Stored in directory: c:\users\bianc\appdata\local\pip\cache\wheels\cc\73\f7\17b6ef934f332f68606b0322a287753ead3212ce9fc3d9bf54
#   Building wheel for liac-arff (setup.py): started
#   Building wheel for liac-arff (setup.py): finished with status 'done'
#   Created wheel for liac-arff: filename=liac_arff-2.5.0-py3-none-any.whl size=11727 sha256=0e2b5fc2268ac33248c105a43947ca290fad5dd05e2a34cabd9d2a39f65e8f0e
#   Stored in directory: c:\users\bianc\appdata\local\pip\cache\wheels\df\2d\e9\05702e5ac2ac33a006f12c36e9b8f32f59f0050a616978ec31
# Successfully built openml liac-arff
# Installing collected packages: xmltodict, pyarrow, minio, liac-arff, openml
# Successfully installed liac-arff-2.5.0 minio-7.1.17 openml-0.14.1 pyarrow-13.0.0 xmltodict-0.13.0

# %% [markdown]
# # Libraries

# %%
# Basic libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Working with files
import os
import glob
import io


# Working with OpenML dataset
import openml
from openml.datasets import edit_dataset, fork_dataset, get_dataset

# %% [markdown]
# # Import Data

# %%
# Download dataset based on OpenML dataset ID

# Name = Crimes-in-Los-angeles-from-2010 
# ID = 43579
# URL = https://www.openml.org/search?type=data&sort=runs&status=active&id=43579

dataset = openml.datasets.get_dataset(43579)

# Print a summary
print(
        f"This is dataset '{dataset.name}', the target feature is "
        f"'{dataset.default_target_attribute}'"
     )

print(f"URL: {dataset.url}")
print(dataset.description[:500])
# Out:
# This is dataset 'Crimes-in-Los-angeles-from-2010', the target feature is 'None'
# URL: https://api.openml.org/data/v1/download/22102404/Crimes-in-Los-angeles-from-2010.arff
# This dataset reflects incidents of crime in the City of Los Angeles dating back to 2010. This data is transcribed from original crime reports that are typed on paper and therefore there may be some inaccuracies within the data. Some location fields with missing data are noted as (0, 0). Address fields are only provided to the nearest hundred block in order to maintain privacy. This data is as accurate as the data in the database.
# This data was taken from data.gov(https://catalog.data.gov/dataset

# %%
# Get the actual data (pandas dataframe and uninteresting metadata)

big_df, *_ = dataset.get_data()
print(f"The lenght of the '{dataset.name}' is = {len(big_df)}")
print(f"The number of features for the '{dataset.name}' is = {len(big_df.columns)}")
big_df.head()
# Out:
# The lenght of the 'Crimes-in-Los-angeles-from-2010' is = 1692056
# The number of features for the 'Crimes-in-Los-angeles-from-2010' is = 26
#    DR_Number Date_Reported Date_Occurred  Time_Occurred  Area_ID    Area_Name  \
# 0    1208575    03/14/2013    03/11/2013           1800       12  77th Street
# 1  102005556    01/25/2010    01/22/2010           2300       20      Olympic
# 2        418    03/19/2013    03/18/2013           2030       18    Southeast
# 3  101822289    11/11/2010    11/10/2010           1800       18    Southeast
# 4   42104479    01/11/2014    01/04/2014           2300       21      Topanga
#
#    Reporting_District  Crime_Code                   Crime_Code_Description  \
# 0                1241         626        INTIMATE PARTNER - SIMPLE ASSAULT
# 1                2071         510                         VEHICLE - STOLEN
# 2                1823         510                         VEHICLE - STOLEN
# 3                1803         510                         VEHICLE - STOLEN
# 4                2133         745  VANDALISM - MISDEAMEANOR (399 OR UNDER)
#
#               MO_Codes  ...                              Weapon_Description  \
# 0  0416 0446 1243 2000  ...  STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)
# 1                 None  ...                                            None
# 2                 None  ...                                            None
# 3                 None  ...                                            None
# 4                 0329  ...                                            None
#
#   Status_Code Status_Description  Crime_Code_1 Crime_Code_2  Crime_Code_3  \
# 0          AO        Adult Other         626.0          NaN           NaN
# 1          IC        Invest Cont         510.0          NaN           NaN
# 2          IC        Invest Cont         510.0          NaN           NaN
# 3          IC        Invest Cont         510.0          NaN           NaN
# 4          IC        Invest Cont         745.0          NaN           NaN
#
#   Crime_Code_4                                  Address Cross_Street  \
# 0          NaN  6300    BRYNHURST                    AV         None
# 1          NaN                                 VAN NESS         15TH
# 2          NaN   200 E  104TH                        ST         None
# 3          NaN                                     88TH         WALL
# 4          NaN  7200    CIRRUS                       WY         None
#
#               Location_
# 0  (33.9829, -118.3338)
# 1  (34.0454, -118.3157)
# 2   (33.942, -118.2717)
# 3  (33.9572, -118.2717)
# 4  (34.2009, -118.6369)
#
# [5 rows x 26 columns]

# %%
big_df.dtypes
# Out:
# DR_Number                   int64
# Date_Reported              object
# Date_Occurred              object
# Time_Occurred               int64
# Area_ID                     uint8
# Area_Name                  object
# Reporting_District          int64
# Crime_Code                  int64
# Crime_Code_Description     object
# MO_Codes                   object
# Victim_Age                float64
# Victim_Sex                 object
# Victim_Descent             object
# Premise_Code              float64
# Premise_Description        object
# Weapon_Used_Code          float64
# Weapon_Description         object
# Status_Code                object
# Status_Description         object
# Crime_Code_1              float64
# Crime_Code_2              float64
# Crime_Code_3              float64
# Crime_Code_4              float64
# Address                    object
# Cross_Street               object
# Location_                  object
# dtype: object

# %%
# Checking for each column the type and the number of distinct and similar values (also see if there are missing values)

for col in big_df.columns:
    print(col)
    print(big_df[col].value_counts())
    print(f"Number of missing values = {big_df[col].isna().sum()}")
    print(f"Type of dataframe column = {big_df[col].dtypes}")
    print('\n')
# Out:
# DR_Number
# 1208575      1
# 151421981    1
# 151421994    1
# 151421993    1
# 151421992    1
#             ..
# 120619874    1
# 120619863    1
# 120619861    1
# 120619860    1
# 182106659    1
# Name: DR_Number, Length: 1692056, dtype: int64
# Number of missing values = 0
# Type of dataframe column = int64
#
#
# Date_Reported
# 08/07/2017    805
# 12/18/2017    794
# 07/24/2017    783
# 10/23/2017    771
# 01/29/2018    763
#              ...
# 02/22/2018    327
# 01/01/2010    324
# 12/25/2010    308
# 02/23/2018    197
# 02/24/2018     54
# Name: Date_Reported, Length: 2977, dtype: int64
# Number of missing values = 0
# Type of dataframe column = object
#
#
# Date_Occurred
# 01/01/2010    2155
# 01/01/2011    2072
# 01/01/2012    1670
# 01/01/2013    1489
# 01/01/2014    1354
#               ...
# 02/09/2013     389
# 02/21/2018     317
# 02/22/2018     185
# 02/23/2018     110
# 02/24/2018      17
# Name: Date_Occurred, Length: 2977, dtype: int64
# Number of missing values = 0
# Type of dataframe column = object
#
#
# Time_Occurred
# 1200    93904
# 1800    50313
# 2000    47025
# 1900    44791
# 1700    44244
#         ...
# 634         6
# 644         6
# 732         6
# 626         6
# 431         1
# Name: Time_Occurred, Length: 1438, dtype: int64
# Number of missing values = 0
# Type of dataframe column = int64
#
#
# Area_ID
# 12    117760
# 3     109185
# 15     92011
# 14     89375
# 18     89061
# 19     85207
# 11     81355
# 9      80618
# 13     79565
# 17     78789
# 21     78454
# 6      77739
# 20     75368
# 5      75203
# 1      72825
# 10     72289
# 2      71504
# 8      70744
# 7      68401
# 16     64832
# 4      61771
# Name: Area_ID, dtype: int64
# Number of missing values = 0
# Type of dataframe column = uint8
#
#
# Area_Name
# 77th Street    117760
# Southwest      109185
# N Hollywood     92011
# Pacific         89375
# Southeast       89061
# Mission         85207
# Northeast       81355
# Van Nuys        80618
# Newton          79565
# Devonshire      78789
# Topanga         78454
# Hollywood       77739
# Olympic         75368
# Harbor          75203
# Central         72825
# West Valley     72289
# Rampart         71504
# West LA         70744
# Wilshire        68401
# Foothill        64832
# Hollenbeck      61771
# Name: Area_Name, dtype: int64
# Number of missing values = 0
# Type of dataframe column = object
#
#
# Reporting_District
# 363     8778
# 645     8372
# 646     7247
# 2156    7151
# 636     6873
#         ...
# 1085       1
# 1300       1
# 967        1
# 1536       1
# 1554       1
# Name: Reporting_District, Length: 1287, dtype: int64
# Number of missing values = 0
# Type of dataframe column = int64
#
#
# Crime_Code
# 624    154801
# 330    130071
# 510    129996
# 310    122010
# 440    120621
#         ...
# 472         3
# 432         3
# 926         2
# 453         1
# 906         1
# Name: Crime_Code, Length: 139, dtype: int64
# Number of missing values = 0
# Type of dataframe column = int64
#
#
# Crime_Code_Description
# BATTERY - SIMPLE ASSAULT                    154801
# BURGLARY FROM VEHICLE                       130071
# VEHICLE - STOLEN                            129996
# BURGLARY                                    122010
# THEFT PLAIN - PETTY (950  UNDER)            120621
#                                              ...
# TILL TAP - ATTEMPT                               3
# BLOCKING DOOR INDUCTION CENTER                   3
# TRAIN WRECKING                                   2
# DRUNK ROLL - ATTEMPT                             1
# FIREARMS RESTRAINING ORDER (FIREARMS RO)         1
# Name: Crime_Code_Description, Length: 142, dtype: int64
# Number of missing values = 398
# Type of dataframe column = object
#
#
# MO_Codes
# 0344                                       183280
# 0329                                        73257
# 1501                                        36425
# 0416                                        25382
# 0325                                        22789
#                                             ...
# 1822 1602 0344 0321                             1
# 0400 0346 0344 1202                             1
# 0906 0371 1223 0344 0400 0416 1822 0355         1
# 0334 0337 0432 1407 0358 0430 0906 1402         1
# 2225 1609 0344                                  1
# Name: MO_Codes, Length: 373145, dtype: int64
# Number of missing values = 183723
# Type of dataframe column = object
#
#
# Victim_Age
# 16.0    42577
# 25.0    39303
# 15.0    38801
# 24.0    38335
# 26.0    38069
#         ...
# 94.0      287
# 95.0      196
# 96.0      143
# 97.0      107
# 98.0       75
# Name: Victim_Age, Length: 90, dtype: int64
# Number of missing values = 136070
# Type of dataframe column = float64
#
#
# Victim_Sex
# M    788015
# F    719157
# X     28846
# H        56
# -         1
# Name: Victim_Sex, dtype: int64
# Number of missing values = 155981
# Type of dataframe column = object
#
#
# Victim_Descent
# H    585667
# W    416373
# B    271192
# O    163521
# X     47502
# A     39894
# K      7564
# F      1991
# I       716
# C       645
# P       295
# J       250
# U       156
# V        92
# G        70
# Z        59
# S        26
# D        15
# L        10
# -         1
# Name: Victim_Descent, dtype: int64
# Number of missing values = 156017
# Type of dataframe column = object
#
#
# Premise_Code
# 101.0    377301
# 501.0    348336
# 502.0    217233
# 108.0    120533
# 102.0     84463
#           ...
# 894.0         1
# 871.0         1
# 893.0         1
# 869.0         1
# 892.0         1
# Name: Premise_Code, Length: 314, dtype: int64
# Number of missing values = 94
# Type of dataframe column = float64
#
#
# Premise_Description
# STREET                                          377301
# SINGLE FAMILY DWELLING                          348336
# MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)    217233
# PARKING LOT                                     120533
# SIDEWALK                                         84463
#                                                  ...
# TACTICAL SIGNIFICANCE                                1
# GREEN LINE (I-105 FWY LEVEL TRAIN)                   1
# MTA - ORANGE LINE - BALBOA                           1
# REDLINE SUBWAY TUNNEL                                1
# MTA - GOLD LINE - LINCOLN/CYPRESS                    1
# Name: Premise_Description, Length: 306, dtype: int64
# Number of missing values = 3273
# Type of dataframe column = object
#
#
# Weapon_Used_Code
# 400.0    341251
# 511.0     46500
# 500.0     43768
# 102.0     26951
# 109.0     10667
#           ...
# 116.0         7
# 120.0         6
# 123.0         3
# 124.0         1
# 222.0         1
# Name: Weapon_Used_Code, Length: 80, dtype: int64
# Number of missing values = 1131579
# Type of dataframe column = float64
#
#
# Weapon_Description
# STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)    341251
# VERBAL THREAT                                      46500
# UNKNOWN WEAPON/OTHER WEAPON                        43768
# HAND GUN                                           26951
# SEMI-AUTOMATIC PISTOL                              10667
#                                                    ...
# MAC-10 SEMIAUTOMATIC ASSAULT WEAPON                    8
# ANTIQUE FIREARM                                        7
# MAC-11 SEMIAUTOMATIC ASSAULT WEAPON                    6
# M1-1 SEMIAUTOMATIC ASSAULT RIFLE                       3
# M-14 SEMIAUTOMATIC ASSAULT RIFLE                       1
# Name: Weapon_Description, Length: 79, dtype: int64
# Number of missing values = 1131580
# Type of dataframe column = object
#
#
# Status_Code
# IC    1309316
# AO     191696
# AA     173501
# JA      13324
# JO       4188
# CC         26
# TH          1
# 13          1
# 19          1
# Name: Status_Code, dtype: int64
# Number of missing values = 2
# Type of dataframe column = object
#
#
# Status_Description
# Invest Cont     1309316
# Adult Other      191696
# Adult Arrest     173501
# Juv Arrest        13324
# Juv Other          4188
# UNK                  31
# Name: Status_Description, dtype: int64
# Number of missing values = 0
# Type of dataframe column = object
#
#
# Crime_Code_1
# 624.0    154986
# 330.0    130170
# 510.0    129990
# 310.0    122016
# 440.0    120592
#           ...
# 453.0         1
# 486.0         1
# 111.0         1
# 431.0         1
# 906.0         1
# Name: Crime_Code_1, Length: 146, dtype: int64
# Number of missing values = 7
# Type of dataframe column = float64
#
#
# Crime_Code_2
# 998.0    87909
# 930.0     2310
# 860.0     1796
# 480.0     1512
# 946.0     1060
#          ...
# 945.0        1
# 978.0        1
# 756.0        1
# 347.0        1
# 471.0        1
# Name: Crime_Code_2, Length: 139, dtype: int64
# Number of missing values = 1584797
# Type of dataframe column = float64
#
#
# Crime_Code_3
# 998.0    2021
# 910.0      53
# 930.0      53
# 999.0      48
# 653.0      33
# 860.0      15
# 753.0      15
# 761.0      15
# 946.0      14
# 521.0      14
# 821.0      11
# 740.0      11
# 745.0      10
# 820.0       9
# 812.0       7
# 933.0       6
# 956.0       6
# 888.0       5
# 626.0       5
# 993.0       4
# 510.0       4
# 997.0       4
# 480.0       4
# 815.0       4
# 810.0       3
# 920.0       3
# 624.0       3
# 902.0       2
# 994.0       2
# 660.0       2
# 830.0       2
# 649.0       2
# 662.0       2
# 410.0       2
# 420.0       2
# 949.0       1
# 93.0        1
# 648.0       1
# 900.0       1
# 310.0       1
# 951.0       1
# 884.0       1
# 625.0       1
# 944.0       1
# 954.0       1
# 668.0       1
# 980.0       1
# 806.0       1
# 850.0       1
# 99.0        1
# 901.0       1
# 520.0       1
# 995.0       1
# 986.0       1
# 440.0       1
# Name: Crime_Code_3, dtype: int64
# Number of missing values = 1689640
# Type of dataframe column = float64
#
#
# Crime_Code_4
# 998.0    64
# 910.0     3
# 930.0     3
# 821.0     1
# 421.0     1
# 999.0     1
# 944.0     1
# 860.0     1
# 521.0     1
# 946.0     1
# 745.0     1
# Name: Crime_Code_4, dtype: int64
# Number of missing values = 1691978
# Type of dataframe column = float64
#
#
# Address
# 6TH                          ST             3908
# 7TH                          ST             3024
# 9300    TAMPA                        AV     2879
# 6TH                                         2428
# 5TH                          ST             2418
#                                             ...
# 2700    SUNSET                       BL        1
# RUSSELL                      ST                1
# KILBOURN                                       1
# 9500    SOUTHWESTERN                 AV        1
# 23900    SCHOENBORN                   ST       1
# Name: Address, Length: 71877, dtype: int64
# Number of missing values = 0
# Type of dataframe column = object
#
#
# Cross_Street
# BROADWAY                           4942
# FIGUEROA                           2985
# VERMONT                      AV    2974
# WESTERN                      AV    2835
# SAN PEDRO                          2831
#                                    ...
# LA VALLE                     ST       1
# TRUMAN                       ST       1
# TYLER                        AV       1
# 105TH                        WY       1
# S  BEVERLY                            1
# Name: Cross_Street, Length: 11522, dtype: int64
# Number of missing values = 1410694
# Type of dataframe column = object
#
#
# Location_
# (0, 0)                  6698
# (34.1016, -118.3387)    3213
# (34.1905, -118.6059)    2325
# (33.9892, -118.3089)    2017
# (34.1576, -118.438)     1804
#                         ...
# (33.9445, -118.4411)       1
# (34.0214, -118.212)        1
# (34.0284, -118.3895)       1
# (34.0241, -118.2699)       1
# (34.0491, -118.2984)       1
# Name: Location_, Length: 61170, dtype: int64
# Number of missing values = 9
# Type of dataframe column = object

# %% [markdown]
# # Preprocesing

# %% [markdown]
# ## Missing Values

# %% [markdown]
# ## Distribution

# %%
# Distribution for datetime type columns 

datetime_fields = ['Date_Reported', 'Date_Occurred']
datetime_df = big_df.copy()

for field in datetime_fields:
    datetime_df[field] = pd.to_datetime(datetime_df[field])
    datetime_df[field + '_year'] = datetime_df[field].dt.year
    
    result = datetime_df.groupby(field + '_year')[field].agg(['count', 'mean']).reset_index()
    
    # Plotting the data
    plt.figure(figsize = (6, 4))
    plt.bar(result[field + '_year'], result['count'], label = 'Count')
    plt.xlabel('Year')
    plt.ylabel('Count')
    plt.title(f'Bucket Distribution by Year for {field}')
    plt.legend()
    plt.show()

# %%
# Distribution for time type columns 

def extract_hour(time_str):
    time_str = str(time_str)
    time_str = time_str.zfill(4)  # Ensure at least 4 digits
    hour_str = time_str[:2]
    return int(hour_str)


datetime_fields = ['Time_Occurred']
datetime_df = big_df.copy()

for field in datetime_fields:
    datetime_df[field + '_hour'] = datetime_df[field].apply(extract_hour)
    
    result = datetime_df.groupby(field + '_hour')[field].agg(['count', 'mean']).reset_index()
    
    # Plotting the data
    plt.figure(figsize = (6, 4))
    plt.bar(result[field + '_hour'], result['count'], label = 'Count')
    plt.xlabel('Hours')
    plt.ylabel('Count')
    plt.title(f'Bucket Distribution by Hours for {field}')
    plt.legend()
    plt.show()

# %%
# Distribution for numerical values - reduced number 
# Area_IDs varying form 1 to 21

datetime_fields = ['Area_Name', 'Victim_Sex', 'Victim_Descent', 'Status_Description']
datetime_df = big_df.copy()

for field in datetime_fields:
    datetime_df[field + '_bucket'] = datetime_df[field]
    
    result = datetime_df.groupby(field + '_bucket')[field].agg(['count']).reset_index()
    
    # Plotting the data
    plt.figure(figsize = (6, 4))
    plt.bar(result[field + '_bucket'], result['count'], label = 'Count')
    plt.xlabel('Bucket')
    plt.xticks(result[field + '_bucket'], result[field + '_bucket'], rotation = 45, ha = 'right')
    plt.ylabel('Count')
    plt.title(f'Bucket Distribution by Bucket for {field}')
    plt.legend()
    plt.show()

# %%
# Victim_Age, Crime_Code_Description, Weapon_Description

# %%
# Distribution for Location type 
# A lot of values with (0, 0) => unknown values theoretically - removed them

def extract_latitude(location_str):
    if location_str is not None:
        if float(location_str.split(',')[0]) != float(0):
            return float(location_str.split(',')[0])
        else: 
            return np.nan
    else:
        return None

def extract_longitude(location_str):
    if location_str is not None:
        if float(location_str.split(',')[1]) != float(0):
            return float(location_str.split(',')[1])
        else: 
            return np.nan
    else:
        return None

datetime_df = big_df.copy()

datetime_df['location'] = datetime_df['Location_'].str.strip('()')
datetime_df['latitude'] = datetime_df['location'].apply(extract_latitude)
datetime_df['longitude'] = datetime_df['location'].apply(extract_longitude)

plt.figure(figsize = (6, 4))
plt.scatter(datetime_df['longitude'], datetime_df['latitude'], marker = 'o', alpha = 0.5)
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title('Scatter Plot of Location Data')
plt.grid(True)
plt.show()

# %% [markdown]
# # Processing
