# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
df = pd.read_csv('../184702-tu-ml-ws-23-loan/loan-10k.lrn.csv')

print(df.shape)
df.head()
# Out:
# (10000, 92)
#       ID  loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate
# 0  24341    12500.0      12500.0          12500.0   36 months      7.21  \
# 1  67534    33850.0      33850.0          33775.0   60 months     20.99
# 2  35080    10000.0      10000.0          10000.0   60 months     20.00
# 3   4828    20250.0      20250.0          20250.0   36 months     14.31
# 4  59259    25000.0      25000.0          25000.0   36 months     14.99
#
#    installment emp_length home_ownership  annual_inc  ...
# 0       387.17   < 1 year       MORTGAGE     81000.0  ...  \
# 1       915.57     1 year       MORTGAGE     80000.0  ...
# 2       264.94   < 1 year           RENT     36580.0  ...
# 3       695.15    9 years           RENT     48700.0  ...
# 4       866.52     1 year       MORTGAGE     85000.0  ...
#
#   debt_settlement_flag issue_d_month issue_d_year earliest_cr_line_month
# 0                    N             6         2018                      6  \
# 1                    N            10         2015                      9
# 2                    N             9         2017                     10
# 3                    N             0         2015                      6
# 4                    N            11         2016                      0
#
#   earliest_cr_line_year  last_pymnt_d_month  last_pymnt_d_year
# 0                  2000                   2               2019  \
# 1                  1984                   2               2019
# 2                  2006                   1               2018
# 3                  1996                   6               2016
# 4                  2002                   2               2019
#
#    last_credit_pull_d_month  last_credit_pull_d_year  grade
# 0                         2                     2019      A
# 1                         2                     2019      E
# 2                        11                     2018      D
# 3                         9                     2017      C
# 4                         2                     2019      C
#
# [5 rows x 92 columns]

# %% [markdown]
# issue_d_month: The month which the loan was funded
# earliest_cr_line_month: The month the borrower's earliest reported credit line was opened
# last_pymnt_d_month: The month of the last payment

# %%
df.describe().T.style.bar(subset=["mean"],color="#606ff2").background_gradient(subset=["std"],cmap="PuBu").background_gradient(subset=["50%"],cmap="PuBu")
# Out:
# <style type="text/css">
# #T_2f925_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #606ff2 26.1%, transparent 26.1%);
# }
# #T_2f925_row0_col2 {
#   background-color: #e5e1ef;
#   color: #000000;
# }
# #T_2f925_row0_col5 {
#   background-color: #a2bcda;
#   color: #000000;
# }
# #T_2f925_row1_col1, #T_2f925_row2_col1, #T_2f925_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #606ff2 8.2%, transparent 8.2%);
# }
# #T_2f925_row1_col2, #T_2f925_row2_col2, #T_2f925_row3_col2, #T_2f925_row21_col2, #T_2f925_row37_col5 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_2f925_row1_col5, #T_2f925_row2_col5, #T_2f925_row3_col5 {
#   background-color: #efe9f3;
#   color: #000000;
# }
# #T_2f925_row4_col1, #T_2f925_row7_col1, #T_2f925_row8_col1, #T_2f925_row11_col1, #T_2f925_row12_col1, #T_2f925_row13_col1, #T_2f925_row15_col1, #T_2f925_row16_col1, #T_2f925_row23_col1, #T_2f925_row25_col1, #T_2f925_row29_col1, #T_2f925_row30_col1, #T_2f925_row31_col1, #T_2f925_row35_col1, #T_2f925_row38_col1, #T_2f925_row39_col1, #T_2f925_row40_col1, #T_2f925_row43_col1, #T_2f925_row44_col1, #T_2f925_row45_col1, #T_2f925_row46_col1, #T_2f925_row47_col1, #T_2f925_row48_col1, #T_2f925_row49_col1, #T_2f925_row50_col1, #T_2f925_row51_col1, #T_2f925_row
col2 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_2f925_row5_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #606ff2 0.2%, transparent 0.2%);
# }
# #T_2f925_row6_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #606ff2 42.9%, transparent 42.9%);
# }
# #T_2f925_row6_col2 {
#   background-color: #a9bfdc;
#   color: #000000;
# }
# #T_2f925_row6_col5 {
#   background-color: #62a2cb;
#   color: #f1f1f1;
# }
# #T_2f925_row9_col1, #T_2f925_row10_col1, #T_2f925_row27_col1, #T_2f925_row28_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #606ff2 0.4%, transparent 0.4%);
# }
# #T_2f925_row9_col5, #T_2f925_row10_col5, #T_2f925_row26_col5, #T_2f925_row27_col5, #T_2f925_row28_col5 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_2f925_row14_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #606ff2 8.9%, transparent 8.9%);
# }
# #T_2f925_row14_col2 {
#   background-color: #ece7f2;
#   color: #000000;
# }
# #T_2f925_row14_col5, #T_2f925_row37_col2 {
#   background-color: #f1ebf5;
#   color: #000000;
# }
# #T_2f925_row17_col1, #T_2f925_row18_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #606ff2 2.4%, transparent 2.4%);
# }
# #T_2f925_row17_col2, #T_2f925_row18_col2 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_2f925_row19_col1, #T_2f925_row20_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #606ff2 6.5%, transparent 6.5%);
# }
# #T_2f925_row19_col2, #T_2f925_row20_col2, #T_2f925_row21_col5 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_2f925_row19_col5, #T_2f925_row20_col5 {
#   background-color: #f4edf6;
#   color: #000000;
# }
# #T_2f925_row21_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #606ff2 5.1%, transparent 5.1%);
# }
# #T_2f925_row22_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #606ff2 1.3%, transparent 1.3%);
# }
# #T_2f925_row22_col2, #T_2f925_row22_col5, #T_2f925_row32_col2, #T_2f925_row71_col5, #T_2f925_row73_col5, #T_2f925_row75_col5, #T_2f925_row77_col5 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_2f925_row24_col1, #T_2f925_row32_col1, #T_2f925_row41_col1, #T_2f925_row42_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #606ff2 0.1%, transparent 0.1%);
# }
# #T_2f925_row26_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #606ff2 1.9%, transparent 1.9%);
# }
# #T_2f925_row26_col2 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_2f925_row33_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #606ff2 80.5%, transparent 80.5%);
# }
# #T_2f925_row33_col2 {
#   background-color: #045382;
#   color: #f1f1f1;
# }
# #T_2f925_row33_col5 {
#   background-color: #1077b4;
#   color: #f1f1f1;
# }
# #T_2f925_row34_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #606ff2 18.7%, transparent 18.7%);
# }
# #T_2f925_row34_col2 {
#   background-color: #dddbec;
#   color: #000000;
# }
# #T_2f925_row34_col5 {
#   background-color: #dad9ea;
#   color: #000000;
# }
# #T_2f925_row36_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #606ff2 7.4%, transparent 7.4%);
# }
# #T_2f925_row36_col2 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_2f925_row36_col5 {
#   background-color: #f6eff7;
#   color: #000000;
# }
# #T_2f925_row37_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #606ff2 6.3%, transparent 6.3%);
# }
# #T_2f925_row66_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #606ff2 100.0%, transparent 100.0%);
# }
# #T_2f925_row66_col2, #T_2f925_row66_col5 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_2f925_row67_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #606ff2 28.9%, transparent 28.9%);
# }
# #T_2f925_row67_col2, #T_2f925_row69_col5 {
#   background-color: #c5cce3;
#   color: #000000;
# }
# #T_2f925_row67_col5 {
#   background-color: #b9c6e0;
#   color: #000000;
# }
# #T_2f925_row68_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #606ff2 12.7%, transparent 12.7%);
# }
# #T_2f925_row68_col2 {
#   background-color: #e9e5f1;
#   color: #000000;
# }
# #T_2f925_row68_col5 {
#   background-color: #ebe6f2;
#   color: #000000;
# }
# #T_2f925_row69_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #606ff2 25.2%, transparent 25.2%);
# }
# #T_2f925_row69_col2 {
#   backgro

# %% [markdown]
# ## Data Preposesing

# %% [markdown]
# #### Data Cleaning

# %%
df.isna().sum()
# Out:
# ID                          0
# loan_amnt                   0
# funded_amnt                 0
# funded_amnt_inv             0
# term                        0
#                            ..
# last_pymnt_d_month          0
# last_pymnt_d_year           0
# last_credit_pull_d_month    0
# last_credit_pull_d_year     0
# grade                       0
# Length: 92, dtype: int64

# %% [markdown]
# #### Feature Engineering

# %%
# Convert Categorical variable with Numerical values
from sklearn.preprocessing import LabelEncoder

loan_CategoricalColumns = df.select_dtypes(include=['object']).columns

for column in loan_CategoricalColumns:
    label_encoder = LabelEncoder()
    df[column] = label_encoder.fit_transform(df[column])

# %%
# Date-Time Features
df['issue_d_month'] = df['issue_d_month'] + 1
df['earliest_cr_line_month'] = df['earliest_cr_line_month'] + 1
df['last_pymnt_d_month'] = df['last_pymnt_d_month'] + 1
df['last_credit_pull_d_month'] = df['last_credit_pull_d_month'] + 1

loan_start_date = pd.to_datetime(df['issue_d_year'].astype(str) + '-' + df['issue_d_month'].astype(str))
last_pymnt_date = pd.to_datetime(df['last_pymnt_d_year'].astype(str) + '-' + df['last_pymnt_d_month'].astype(str))
df['loan_age'] = (last_pymnt_date - loan_start_date).dt.days

credit_start_date = pd.to_datetime(df['earliest_cr_line_year'].astype(str) + '-' + df['earliest_cr_line_month'].astype(str))
last_credit_pull_date = pd.to_datetime(df['last_credit_pull_d_year'].astype(str) + '-' + df['last_credit_pull_d_month'].astype(str))
df['credit_history_length'] = (last_credit_pull_date - credit_start_date).dt.days

columnsToDrop = ['issue_d_year','issue_d_month','earliest_cr_line_year','earliest_cr_line_month','last_pymnt_d_month','last_pymnt_d_year','last_credit_pull_d_month','last_credit_pull_d_year']
df=df.drop(columnsToDrop,axis=1)

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import f1_score, roc_auc_score
from sklearn.model_selection import train_test_split
import lightgbm as lgb

# %%
ycol = 'grade'
feature_names = list(
    filter(lambda x: x not in [ycol], df.columns))

X = df[feature_names]
y = df['grade']

train_data,test_data,train_y,test_y = \
                train_test_split(X,y,test_size=0.2,random_state=1,shuffle=True,stratify=df.grade)

# %%
model = lgb.LGBMClassifier(objective='multiclass',
                           boosting_type='gbdt',
                           tree_learner='serial',
                           num_leaves=64,
                           max_depth=8,
                           learning_rate=0.02,
                           n_estimators=10000,
                           subsample=0.8,
                           feature_fraction=0.8,
                           reg_alpha=0.3,
                           reg_lambda=0.5,
                           random_state=2020,
                           is_unbalance=True)

oof = []
prediction = test_data[['ID']]
prediction[f'{ycol}_0'] = 0
prediction[f'{ycol}_1'] = 0
df_importance_list = []

def f1_score_custom(y_true, y_pred):
    y_pred = y_pred.round()
    return 'f1', f1_score(y_true, y_pred), True
# Out:
# /var/folders/mr/gq2bpcr56zs7jv_mwwgcdgr00000gn/T/ipykernel_5581/4017199640.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   prediction[f'{ycol}_0'] = 0
# /var/folders/mr/gq2bpcr56zs7jv_mwwgcdgr00000gn/T/ipykernel_5581/4017199640.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   prediction[f'{ycol}_1'] = 0

# %%
kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=2020)

# %%
feature_names = list(
    filter(lambda x: x not in [ycol,'ID'], df.columns))

# %%
# merge train_data and train_y
train = pd.concat([train_data,train_y],axis=1)

# %%
for fold_id, (trn_idx, val_idx) in enumerate(kfold.split(train_data[feature_names], train_y)):
    X_train = train_data.iloc[trn_idx]
    Y_train = train_y.iloc[trn_idx]

    X_val = train_data.iloc[val_idx]
    Y_val = train_y.iloc[val_idx]

    print('\nFold_{} Training ================================\n'.format(fold_id+1))
    

    
    lgb_model = model.fit(X_train,
                          Y_train,
                          eval_names=['train', 'valid'],
                          eval_set=[(X_train, Y_train), (X_val, Y_val)],
                          verbose=500,
                          eval_metric=lambda y_true, y_pred: f1_score_custom(y_true, y_pred),
                          early_stopping_rounds=50)

    pred_val = lgb_model.predict_proba(
        X_val, num_iteration=lgb_model.best_iteration_)
    
    df_oof = train.iloc[val_idx][['ID', ycol]].copy()
    df_oof[f'{ycol}_0'] = pred_val[:,0]
    df_oof[f'{ycol}_1'] = pred_val[:,1]
    oof.append(df_oof)

    pred_test = lgb_model.predict_proba(
        test[feature_names], num_iteration=lgb_model.best_iteration_)
    prediction[f'{ycol}_0'] += pred_test[:,0] / kfold.n_splits
    prediction[f'{ycol}_1'] += pred_test[:,1] / kfold.n_splits

    df_importance = pd.DataFrame({
        'column': feature_names,
        'importance': lgb_model.feature_importances_,
    })
    df_importance_list.append(df_importance)

    del lgb_model, pred_val, pred_test, X_train, Y_train, X_val, Y_val
    gc.collect()

df_importance = pd.concat(df_importance_list)
df_importance = df_importance.groupby(['column'])['importance'].agg(
    'mean').sort_values(ascending=False).reset_index()
df_importance
# Out:
# Le Kernel s’est bloqué lors de l’exécution du code dans la cellule active ou une cellule précédente. Veuillez vérifier le code dans la ou les cellules pour identifier une cause possible de l’échec. Cliquez <a href='https://aka.ms/vscodeJupyterKernelCrash'>ici</a> pour plus d’informations. Pour plus d’informations, consultez Jupyter <a href='command:jupyter.viewOutput'>log</a>.

# %%
from sklearn.model_selection import train_test_split
import lightgbm as lgb

X = df[feature_names]
y = df['grade']
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
train_data_all,test_data,train_y_all,test_y = \
                train_test_split(X, y,test_size=0.2,random_state=1,shuffle=True,stratify=df.grade)
# 再从训练集中分割出训练集与验证集
train_data,val_data,train_y,val_y = \
                train_test_split(train_data_all, train_y_all,test_size=0.2,random_state=1,shuffle=True, stratify=train_y_all)

# %%
clf = lgb.LGBMClassifier(objective="multiclass", n_estimators=10)

# %%
clf.fit(train_data,train_y,early_stopping_rounds=5,eval_set=[(val_data,val_y)],verbose=10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/lulu/Downloads/184702-tu-ml-ws-23-loan/loan.ipynb Cellule 15 line 1
# ----> <a href='vscode-notebook-cell:/Users/lulu/Downloads/184702-tu-ml-ws-23-loan/loan.ipynb#X33sZmlsZQ%3D%3D?line=0'>1</a> clf.fit(train_data,train_y,early_stopping_rounds=5,eval_set=[(val_data,val_y)],verbose=10)
#
# NameError: name 'clf' is not defined

# %%
# 模型预测
y_pred = clf.predict(test_data)

# 查看分类结果
from sklearn.metrics import classification_report
print(classification_report(test_y, y_pred))

# %%
# 将任务1训练得到的模型，使用pickle进行保存
import pickle
pickle.dump(booster, open('model.pickle', 'wb'))

# 从pickle加载模型
model_pickle = pickle.load(open('model.pickle','rb'))
# 模型预测
y_pred_pickle = model_pickle.predict(test_data)
# 预测结果
y_pred_pickle
